# %%
# !pip install numpy
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in c:\users\harish\anaconda3\lib\site-packages (1.21.5)
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\harish\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('1.jpg')
# cv2.imshow("Original Image", image)
# cv2.waitKey(0)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1E1B4BF8D00>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=1024x768 at 0x1E1B33BB0D0>

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=1024x768 at 0x1E1B33B1DF0>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=1024x768 at 0x1E1B33D49D0>

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=150)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=1024x768 at 0x1E1B33B1370>
